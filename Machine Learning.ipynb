# %%
import pandas as pd
import random as rand
import py_entitymatching as em
rand.seed()

# %%
#A = em.read_csv_metadata('YW.csv', key='index')
#A = em.read_csv_metadata('Boats.csv', key='index')
cand = em.load_table('./candidate_set.csv')
#cand.set_index('_id')

# %%
s = em.sample_table(cand, 400)
# Out:
# Requested metadata ( ltable ) for the given DataFrame is not present in the catalog
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-b61377cd63ea> in <module>()
# ----> 1 s = em.sample_table(cand, 400)
#
# /home/dhayes/bin/anaconda3/lib/python3.5/site-packages/py_entitymatching-0.1.0-py3.5.egg/py_entitymatching/sampler/single_table.py in sample_table(table, sample_size, replace, verbose)
#      89     # # Second, get the metadata
#      90     key, fk_ltable, fk_rtable, ltable, rtable, l_key, r_key = \
# ---> 91         cm.get_metadata_for_candset(table, logger, verbose)
#      92
#      93     # # Third, validate the metadata
#
# /home/dhayes/bin/anaconda3/lib/python3.5/site-packages/py_entitymatching-0.1.0-py3.5.egg/py_entitymatching/catalog/catalog_manager.py in get_metadata_for_candset(candset, lgr, verbose)
# ...

# %%
# Out:
#       index used power       price_US$  year     class hull_material  \
# 3699   3700  yes   yes  Call for Price  2017  Bowrider    Fiberglass
# 1656   1657  yes   yes           62999  2015  Bowrider    Fiberglass
# 4117   4118  yes   yes           28164  2016  Bowrider    Fiberglass
# 477     478  yes   yes  Call for Price  2016  Bowrider    Fiberglass
# 462     463  yes   yes           59900  2008  Bowrider    Fiberglass
#
#                             seller  Length_ft           location  \
# 3699           MarineMax Inc.\n            19        Cumming, GA
# 1656          Boats of Dallas\n            24  St. Augustine, FL
# 4117       Windermere Aquatic\n            18     United Kingdom
# 477            MarineMax Inc.\n            29          Miami, FL
# 462   On The Dock Yacht Sales\n            29     Fort Myers, FL
#
#                                  Make_Model
# 3699                        Sea Ray SPX 190
# 1656                   Formula 240 Bowrider
# ...

# %%
GG = cand.sample(400)

# %%
#ltable_index = B table
#rtable_index = A table
#for index, row in GG.iterrows():
    #print(row['ltable_index'])
    #print(row)

# %%
GG.head(100)
# Out:
#           _id  ltable_index  rtable_index  ltable_Length_ft  \
# 870    822603          6263          3145                21
# 2894  2706937          7042          3358                20
# 3162  2980277          8910          3978                18
# 1239  1377298          3535          2010                23
# 2119  1919873          1648          1117                26
# 589    498968          5482          2844                21
# 2572  2311173          4797          2589                22
# 765    678876          5916          3076                21
# 2081  1880731          1516          1047                26
# 2072  1863239          1457          1019                26
# 1774  1722783           608           488                29
# 1990  1811832          1271           830                27
# 1621  1684374           317           257                31
# 2104  1902677          1590          1089                26
# 2430  2121557          4327          2382                22
# ...
